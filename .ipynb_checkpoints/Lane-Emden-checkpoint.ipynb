# %% [markdown]
# This notebook is designed to show the solutions to the Lane-Emden equation via the Runge-Kutta 4th order solver

# %% [markdown]
# In the first block, we import the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML, display, Math
import tabulate

# %% [markdown]
# We define the classes necessary to carry out the Runge-Kutta 4th order integration. runkutt is the integrater and the g function will update the function and the first derivative

# %%
def runkutt(y,t,dt,n):
#The method implemented is the one described in An Introduction to Computational Physics, 2nd Edition
# by Tao Pang    
    c1 = np.zeros(2)
    c2 = np.zeros(2)
    c3 = np.zeros(2)
    c4 = np.zeros(2)
  
    c1 = g(y,t,n)
    
    c2 = y + dt*c1/2
    c2 = g(c2,t+dt/2,n)
    
    c3 = y + dt*c2/2
    c3 = g(c3,t+dt/2,n)
    
    c4 = y + dt*c3/2 
    c4 = g(c4,t+dt/2,n)
    
    return y + dt*(c1 + 2*(c2+c3) +c4)/6
    

def g(y,t,n):
# updates the function and the first derivative    
    v = np.zeros(2)
    
    v[0] = -y[1]/t**2
    v[1] = (y[0]**n)*t**2
    
    return v

# %%
def newton_raphson(x,y,dy,x0,j):
# since we on't have an explicit function, we need to interpolate the data at every new "root"
# until convergence. this is the main reason for the long runtime    
    h = y[j]/dy[j]
    while abs(h) >=1e-10:
        x0 -= h
        y0  = np.interp(x0,x,y)
        dy0 = np.interp(x0,x,dy)
        h   = y0/dy0
    return x0

# %% [markdown]
# initializing the variables and loop over n and set up plots

# %%
def main ():
    m    = 1000
    dt   = 20/m
    table = np.empty((5,3))
    
#figsize controls the plot's resolution, a 1080p (1920x1080) resolution would be reported
#as figsize = (19.20,10.80)

    plt.figure(figsize=(10.24,7.68))
    plt.xlabel(r'$\xi$',fontsize = '18')
    plt.ylabel(r'$\Theta(\xi)$',fontsize='18')
    plt.ylim([-1,1])
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    plt.rcParams['font.size'] = 18
    
    for n in range(0,6):
        
        y1 = np.zeros(m)
        y2 = np.zeros(m)
    
        y  = np.zeros(2)
        y[0] = 1
        y[1] = 0
    
        y1[0] = y[0]
        y2[0] = y[1]
        t = np.zeros(m)
        
        for i in range (m):
            t[i]  = dt*(i+1)
            y     = runkutt(y,t[i],dt,n)
            y1[i] = y[0]
            y2[i] = y[1]
            
        plt.plot(t,y1,label = 'n = ' + str(n))
        if n!=5:
            dy = np.gradient(y1,dt)          
            i = 0
            for i in range(m):
                if y1[i] < 0:
                    break            

            t0 = t[i-1]
            t1 = newton_raphson(t,y1,dy,t0,i-1)
            
            d_theta_1 = abs(np.interp(t1,t,dy)) 
            
            plt.plot(t1,0,'*',color='black')
            table[n] = [n,t1,d_theta_1]
        
    plt.grid(color = 'black')
    plt.legend()
    plt.show()
    display(Math(r'n  \;\;\;\;\;  \xi_{1}   \;\;\;\;\; -\frac{d\theta}{d\xi}\Bigr|_{\xi=\xi_{1}}'))
    display(HTML(tabulate.tabulate(table, tablefmt='html')))
    

    
if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: overflow encountered in double_scalars
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:1065: RuntimeWarning: invalid value encountered in subtract
#   out[tuple(slice1)] = (f[tuple(slice4)] - f[tuple(slice2)]) / (2. * ax_dx)
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:1093: RuntimeWarning: invalid value encountered in double_scalars
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_n
# $\displaystyle n  \;\;\;\;\;  \xi_{1}   \;\;\;\;\; -\frac{d\theta}{d\xi}\Bigr|_{\xi=\xi_{1}}$
# <table>
# <tbody>
# <tr><td style="text-align: right;">0</td><td style="text-align: right;"> 2.43612</td><td style="text-align: right;">0.816497  </td></tr>
# <tr><td style="text-align: right;">1</td><td style="text-align: right;"> 3.12329</td><td style="text-align: right;">0.31996   </td></tr>
# <tr><td style="text-align: right;">2</td><td style="text-align: right;"> 4.32581</td><td style="text-align: right;">0.128195  </td></tr>
# <tr><td style="text-align: right;">3</td><td style="text-align: right;"> 6.84772</td><td style="text-align: right;">0.0428836 </td></tr>
# <tr><td style="text-align: right;">4</td><td style="text-align: right;">14.8213 </td><td style="text-align: right;">0.00816061</td></tr>
# </tbody>
# </table>
